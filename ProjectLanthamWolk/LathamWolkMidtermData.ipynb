# %% [markdown]
# <a href="https://colab.research.google.com/github/CoWoGeo/PUS2022_CWolk/blob/main/ProjectLanthamWolk/LanthamWolkMidtermData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install geopandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.0 MB 4.2 MB/s
# ...
#      |████████████████████████████████| 16.7 MB 59.7 MB/s
# ...
#      |████████████████████████████████| 6.3 MB 41.6 MB/s
# ...

# %%
import geopandas as gpd

# %%
import numpy as np

# %%
import pandas as pd

# %%
licenses = gpd.GeoDataFrame.from_file("https://phl.carto.com/api/v2/sql?q=SELECT+*+FROM+business_licenses&filename=business_licenses&format=shp&skipfields=cartodb_id")

# %%
licenses.head()
# Out:
#    objectid  addressobj             address unit_type unit_num         zip  \
# 0        27  15326419.0      1816 MARKET ST         #       G1  19103-3717
# 1        28  15412910.0  3800 LANCASTER AVE         #       2A  19104-2318
# 2        29  15878447.0     7673 WINSTON RD      None     None  19118-3528
# 3        30  15753726.0   4200 WOODLAND AVE      None     None  19104-4446
# 4        31  15494453.0     4600 N BROAD ST      None     None  19140-1218
#
#   censustrac parcel_id_ opa_accoun                           opa_owner  ...  \
# 0       4.02      19002       None                                None  ...
# 1         91      90715  871286150                           CHEN RONG  ...
# 2        257      56632  882970820      MEKIS JOSEPH A, MEKIS VERONICA  ...
# 3         77     589969  773501000  PHILA COLLEGE OF, PHARMACY SCIENCE  ...
# 4        281      10441  882929625                       SIDNEY BOOKER  ...
#
# ...

# %%
licenses.columns()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-41e6a269da81> in <module>
# ----> 1 licenses.columns()
#
# TypeError: 'Index' object is not callable

# %%
licenses
# Out:
#         objectid   addressobj             address unit_type unit_num  \
# 0             27   15326419.0      1816 MARKET ST         #       G1
# 1             28   15412910.0  3800 LANCASTER AVE         #       2A
# 2             29   15878447.0     7673 WINSTON RD      None     None
# 3             30   15753726.0   4200 WOODLAND AVE      None     None
# 4             31   15494453.0     4600 N BROAD ST      None     None
# ...          ...          ...                 ...       ...      ...
# 393346    391987  133999146.0      2430 N 25TH ST      None     None
# 393347    391988  135245705.0      4801 N 11TH ST         #        2
# 393348    391989  138831647.0       627 N 18TH ST         #      10B
# 393349    391990  130053868.0  1244 N LAWRENCE ST      None     None
# 393350    391991   15529368.0  5334 HAVERFORD AVE      None     None
#
#                zip censustrac parcel_id_ opa_accoun  \
# 0       19103-3717       4.02      19002       None
# ...

# %%
print(licenses.columns.tolist())
# Out:
# ['objectid', 'addressobj', 'address', 'unit_type', 'unit_num', 'zip', 'censustrac', 'parcel_id_', 'opa_accoun', 'opa_owner', 'licensenum', 'revenuecod', 'licensetyp', 'rentalcate', 'initialiss', 'mostrecent', 'expiration', 'inactiveda', 'licensesta', 'numberofun', 'owneroccup', 'legalfirst', 'legallastn', 'legalname', 'legalentit', 'business_n', 'business_m', 'ownerconta', 'ownercon_1', 'ownercon_2', 'ownercon_3', 'ownercon_4', 'ownercon_5', 'ownercon_6', 'ownercon_7', 'ownercon_8', 'ownercon_9', 'geocode_x', 'geocode_y', 'council_di', 'posse_jobi', 'geometry']

# %%
licenses.info
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 393351 entries, 0 to 393350
# Data columns (total 42 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   objectid    393351 non-null  int64
#  1   addressobj  373633 non-null  float64
#  2   address     376165 non-null  object
#  3   unit_type   115488 non-null  object
#  4   unit_num    114961 non-null  object
#  5   zip         376139 non-null  object
#  6   censustrac  375641 non-null  object
#  7   parcel_id_  374332 non-null  object
#  8   opa_accoun  366104 non-null  object
#  9   opa_owner   365848 non-null  object
#  10  licensenum  393351 non-null  object
#  11  revenuecod  393351 non-null  object
#  12  licensetyp  393351 non-null  object
#  13  rentalcate  228235 non-null  object
#  14  initialiss  393351 non-null  object
#  15  mostrecent  393351 non-null  object
#  16  expiration  384272 non-null  object
#  17  inactiveda  226649 non-null  object
# ...

# %% [markdown]
# # <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 393351 entries, 0 to 393350
# Data columns (total 42 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   objectid    393351 non-null  int64
#  1   addressobj  373633 non-null  float64
#  2   address     376165 non-null  object
#  3   unit_type   115488 non-null  object
#  4   unit_num    114961 non-null  object
#  5   zip         376139 non-null  object
#  6   censustrac  375641 non-null  object
#  7   parcel_id_  374332 non-null  object
#  8   opa_accoun  366104 non-null  object
#  9   opa_owner   365848 non-null  object
#  10  licensenum  393351 non-null  object
#  11  revenuecod  393351 non-null  object
#  12  licensetyp  393351 non-null  object
#  13  rentalcate  228235 non-null  object
#  14  initialiss  393351 non-null  object
#  15  mostrecent  393351 non-null  object
#  16  expiration  384272 non-null  object
#  17  inactiveda  226649 non-null  object
#  18  licensesta  393351 non-null  object
#  19  numberofun  271504 non-null  float64
#  20  owneroccup  249032 non-null  object
#  21  legalfirst  219854 non-null  object
#  22  legallastn  219849 non-null  object
#  23  legalname   392837 non-null  object
#  24  legalentit  392836 non-null  object
#  25  business_n  392913 non-null  object
#  26  business_m  391856 non-null  object
#  27  ownerconta  9601 non-null    object
#  28  ownercon_1  9595 non-null    object
#  29  ownercon_2  9601 non-null    object
#  30  ownercon_3  9556 non-null    object
#  31  ownercon_4  9601 non-null    object
#  32  ownercon_5  893 non-null     object
#  33  ownercon_6  893 non-null     object
#  34  ownercon_7  911 non-null     object
#  35  ownercon_8  950 non-null     object
#  36  ownercon_9  911 non-null     object
#  37  geocode_x   375639 non-null  float64
#  38  geocode_y   375639 non-null  float64
#  39  council_di  375633 non-null  object
#  40  posse_jobi  393351 non-null  object
#  41  geometry    375639 non-null  geometry
# dtypes: float64(4), geometry(1), int64(1), object(36)
# memory usage: 126.0+ MB

# %%
# licenses.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 393351 entries, 0 to 393350
# Data columns (total 42 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   objectid    393351 non-null  int64
#  1   addressobj  373633 non-null  float64
#  2   address     376165 non-null  object
#  3   unit_type   115488 non-null  object
#  4   unit_num    114961 non-null  object
#  5   zip         376139 non-null  object
#  6   censustrac  375641 non-null  object
#  7   parcel_id_  374332 non-null  object
#  8   opa_accoun  366104 non-null  object
#  9   opa_owner   365848 non-null  object
#  10  licensenum  393351 non-null  object
#  11  revenuecod  393351 non-null  object
#  12  licensetyp  393351 non-null  object
#  13  rentalcate  228235 non-null  object
#  14  initialiss  393351 non-null  object
#  15  mostrecent  393351 non-null  object
#  16  expiration  384272 non-null  object
#  17  inactiveda  226649 non-null  object
# ...

# %%
firstviolations = gpd.GeoDataFrame.from_file("https://phl.carto.com/api/v2/sql?filename=violations&format=shp&skipfields=cartodb_id&q=SELECT%20*%20FROM%20violations%20WHERE%20violationdate%20%3E=%20%272013-01-01%27%20AND%20violationdate%20%3C%20%272016-01-01%27")

# %%
firstviolations.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 323545 entries, 0 to 323544
# Data columns (total 31 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   objectid    323545 non-null  int64
#  1   addressobj  323545 non-null  object
#  2   parcel_id_  26 non-null      object
#  3   casenumber  323545 non-null  object
#  4   casecreate  311564 non-null  object
#  5   casecomple  268734 non-null  object
#  6   casetype    26 non-null      object
#  7   casestatus  323545 non-null  object
#  8   caserespon  311554 non-null  object
#  9   casepriori  311544 non-null  object
#  10  violationn  323545 non-null  object
#  11  violationd  323545 non-null  object
#  12  violationc  323545 non-null  object
#  13  violatio_1  323452 non-null  object
#  14  violations  318967 non-null  object
#  15  violationr  5 non-null       object
#  16  violatio_2  5 non-null       object
#  17  mostrecent  323354 non-null  object
# ...

# %%
firstviolations
# Out:
#         objectid addressobj parcel_id_ casenumber  casecreate  casecomple  \
# 0            960  134326208      40813     574371  2017-03-01  2021-03-31
# 1           1372   15873319      64089     575282  2017-03-10        None
# 2           1373   15873319      64089     575282  2017-03-10        None
# 3           1374   15873319      64089     575282  2017-03-10        None
# 4           1375   15873319      64089     575282  2017-03-10        None
# ...          ...        ...        ...        ...         ...         ...
# 323540   1639658      99953       None     401313  2013-09-10  2014-01-15
# 323541   1639662      99955       None     400064  2013-08-29  2013-09-13
# 323542   1639663      99955       None     400064  2013-08-29  2013-09-13
# 323543   1639664      99955       None     400064  2013-08-29  2013-09-13
# 323544   1638701      99789       None     467778  2015-02-04  2015-02-19
#
#                    casetype    casestatus                     caserespon  \
# ...

# %%
secondviolations = gpd.GeoDataFrame.from_file("https://phl.carto.com/api/v2/sql?filename=violations&format=shp&skipfields=cartodb_id&q=SELECT%20*%20FROM%20violations%20WHERE%20violationdate%20%3E=%20%272016-01-01%27%20AND%20violationdate%20%3C%20%272019-01-01%27")

# %%
recentviolations = gpd.GeoDataFrame.from_file("https://phl.carto.com/api/v2/sql?filename=violations&format=shp&skipfields=cartodb_id&q=SELECT * FROM violations WHERE violationdate >= '2019-01-01'")
# Out:
# ---------------------------------------------------------------------------
# InvalidURL                                Traceback (most recent call last)
# <ipython-input-22-aac45e2d56b7> in <module>
# ----> 1 recentviolations = gpd.GeoDataFrame.from_file("https://phl.carto.com/api/v2/sql?filename=violations&format=shp&skipfields=cartodb_id&q=SELECT * FROM violations WHERE violationdate >= '2019-01-01'")
#
# /usr/local/lib/python3.7/dist-packages/geopandas/geodataframe.py in from_file(cls, filename, **kwargs)
#     524
#     525         """
# --> 526         return geopandas.io.file._read_file(filename, **kwargs)
#     527
#     528     @classmethod
#
# /usr/local/lib/python3.7/dist-packages/geopandas/io/file.py in _read_file(filename, bbox, mask, rows, **kwargs)
#     168
#     169     if _is_url(filename):
# --> 170         req = _urlopen(filename)
#     171         path_or_bytes = req.read()
#     172         reader = fiona.BytesCollection
#
# ...

# %%
secondviolations
# Out:
#         objectid addressobj parcel_id_ casenumber  casecreate  casecomple  \
# 0             51  163531503     532397     569117  2017-01-10        None
# 1             52  163531503     532397     569117  2017-01-10        None
# 2             53  163531503     532397     569117  2017-01-10        None
# 3             54  163531503     532397     569117  2017-01-10        None
# 4             55  163531503     532397     569117  2017-01-10        None
# ...          ...        ...        ...        ...         ...         ...
# 333779   1639666      99955       None     584921  2017-05-22  2017-06-12
# 333780   1639670      99956       None     540446  2016-06-20  2016-08-04
# 333781   1639671      99956       None     540446  2016-06-20  2016-08-04
# 333782   1639816      99998       None     528521  2016-04-19        None
# 333783   1639817      99998       None     583448  2017-05-11        None
#
#                    casetype    casestatus                     caserespon  \
# ...

# %%
secondviolations.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 333784 entries, 0 to 333783
# Data columns (total 31 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   objectid    333784 non-null  int64
#  1   addressobj  333784 non-null  object
#  2   parcel_id_  20623 non-null   object
#  3   casenumber  333784 non-null  object
#  4   casecreate  330820 non-null  object
#  5   casecomple  294395 non-null  object
#  6   casetype    20686 non-null   object
#  7   casestatus  333784 non-null  object
#  8   caserespon  330610 non-null  object
#  9   casepriori  330806 non-null  object
#  10  violationn  333784 non-null  object
#  11  violationd  333784 non-null  object
#  12  violationc  333784 non-null  object
#  13  violatio_1  333679 non-null  object
#  14  violations  331473 non-null  object
#  15  violationr  8909 non-null    object
#  16  violatio_2  8909 non-null    object
#  17  mostrecent  324863 non-null  object
# ...

# %%
complaints = gpd.GeoDataFrame.from_file("https://phl.carto.com/api/v2/sql?q=SELECT+*+FROM+complaints&filename=complaints&format=shp&skipfields=cartodb_id")

# %%
complaints.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 811125 entries, 0 to 811124
# Data columns (total 27 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   objectid    811125 non-null  int64
#  1   addressobj  810749 non-null  object
#  2   address     810616 non-null  object
#  3   unit_type   727 non-null     object
#  4   unit_num    5798 non-null    object
#  5   zip         810612 non-null  object
#  6   censustrac  810464 non-null  object
#  7   parcel_id_  805063 non-null  object
#  8   opa_accoun  802961 non-null  object
#  9   opa_owner   806119 non-null  object
#  10  complaintn  811125 non-null  object
#  11  casenumber  100788 non-null  object
#  12  complaintc  811125 non-null  object
#  13  complain_1  811125 non-null  object
#  14  unitrespon  164725 non-null  object
#  15  ticket_num  125207 non-null  object
#  16  complaintd  811125 non-null  object
#  17  complaints  164725 non-null  object
# ...

# %%
# why won't this work
# deprecycling = gpd.read_file("https://www.pasda.psu.edu/json/LandRecyclingCleanupLocations2022_10.geojson")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-6db668418263> in <module>
# ----> 1 deprecycling = gpd.read_file("https://www.pasda.psu.edu/json/LandRecyclingCleanupLocations2022_10.geojson")
#
# TypeError: 'str' object is not callable

# %%
recyclingdep = gpd.GeoDataFrame.from_file("https://www.pasda.psu.edu/download/dep/LandRecyclingCleanupLocations2022_10.zip")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-124766253f17> in <module>
# ----> 1 recyclingdep = gpd.GeoDataFrame.from_file("https://www.pasda.psu.edu/download/dep/LandRecyclingCleanupLocations2022_10.zip")
#
# TypeError: 'str' object is not callable

# %%
deptrashland = gpd.GeoDataFrame.from_file("https://www.pasda.psu.edu/json/LandRecyclingCleanupLocations2022_10.geojson")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-906499d3d23e> in <module>
# ----> 1 deptrashland = gpd.GeoDataFrame.from_file("https://www.pasda.psu.edu/json/LandRecyclingCleanupLocations2022_10.geojson")
#
# TypeError: 'str' object is not callable

# %%
water = gpd.GeoDataFrame.from_file("https://www.pasda.psu.edu/download/dep/LandRecyclingCleanupLocations2022_10.zip")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-aa47981f7d39> in <module>
# ----> 1 water = gpd.GeoDataFrame.from_file("https://www.pasda.psu.edu/download/dep/LandRecyclingCleanupLocations2022_10.zip")
#
# TypeError: 'str' object is not callable
